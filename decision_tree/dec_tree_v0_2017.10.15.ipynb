# %% [markdown]
# # MSDS 7331 Data Mining: 1st decision tree model
#
# ***
#
# Team: Andrew Abbott, Vivek Bejugama, Patrick McDevitt, Preeti Swaminathan

# %% [markdown]
# ### Data Loading

# %% [markdown]
# #### Import Required Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter('ignore',DeprecationWarning)
import seaborn as sns
import time

# %% [markdown]
# #### Import Data from .csv file

# %%
data_dir = '../data/'
data_file = 'mashable_clean_dataset_for_LR_and_SVM.csv'

file_2_read = data_dir + data_file
df = pd.read_csv(file_2_read)

# %% [markdown]
# #### Strip leading spaces from column names

# %% [markdown]
# An initial summary of the dataset attribute follows along with the simple statistics of the numeric attributes.

# %%
#df.info()

# %%
df.describe().T
# Out:
#                                    count           mean            std  \
# n_tokens_title                   39644.0      10.398749       2.114037
# num_keywords                     39644.0       7.223767       1.909130
# data_channel_is_lifestyle        39644.0       0.052946       0.223929
# data_channel_is_entertainment    39644.0       0.178009       0.382525
# data_channel_is_socmed           39644.0       0.058597       0.234871
# kw_avg_min                       39644.0     312.366967     620.783887
# kw_max_max                       39644.0  752324.066694  214502.129573
# kw_avg_max                       39644.0  259281.938083  135102.247285
# weekday_is_monday                39644.0       0.168020       0.373889
# weekday_is_tuesday               39644.0       0.186409       0.389441
# weekday_is_wednesday             39644.0       0.187544       0.390353
# weekday_is_thursday              39644.0       0.183306       0.386922
# weekday_is_friday                39644.0       0.143805       0.350896
# is_weekend                       39644.0       0.130915       0.337312
# LDA_00                           39644.0       0.184599       0.262975
# LDA_01                           39644.0       0.141256       0.219707
# LDA_02                           39644.0       0.216321       0.282145
# LDA_03                           39644.0       0.223770       0.295191
# LDA_04                           39644.0       0.234029       0.289183
# global_subjectivity              39644.0       0.443370       0.116685
# global_rate_positive_words       39644.0       0.039625       0.017429
# rate_positive_words              39644.0       0.682150       0.190206
# max_positive_polarity            39644.0       0.756728       0.247786
# min_negative_polarity            39644.0      -0.521944       0.290290
# max_negative_polarity            39644.0      -0.107500       0.095373
# title_sentiment_polarity         39644.0       0.071425       0.265450
# abs_title_subjectivity           39644.0       0.341843       0.188791
# year                             39644.0    2013.540939       0.498327
# ln_n_tokens_content              39644.0       5.889971       1.255442
# ln_num_hrefs                     39644.0       2.156564       0.809445
# ln_num_imgs                      39644.0       1.116427       0.973755
# ln_num_videos                    39644.0       0.400420       0.680486
# ln_kw_max_min                    39644.0       6.393888       1.311168
# ln_kw_min_max                    39644.0       5.045209       4.521016
# ln_kw_avg_avg                    39644.0       7.976327       0.489467
# ln_self_reference_avg_sharess    39644.0       6.667697       3.280186
# ln_global_rate_negative_words    39644.0       0.016419       0.010571
# ln_min_positive_polarity         39644.0       0.089255       0.060260
# ln_abs_title_sentiment_polarity  39644.0       0.128709       0.173844
#
#                                     min            25%            50%  \
# n_tokens_title                      2.0       9.000000      10.000000
# num_keywords                        1.0       6.000000       7.000000
# data_channel_is_lifestyle           0.0       0.000000       0.000000
# data_channel_is_entertainment       0.0       0.000000       0.000000
# data_channel_is_socmed              0.0       0.000000       0.000000
# kw_avg_min                         -1.0     141.750000     235.500000
# kw_max_max                          0.0  843300.000000  843300.000000
# kw_avg_max                          0.0  172846.875000  244572.222223
# weekday_is_monday                   0.0       0.000000       0.000000
# weekday_is_tuesday                  0.0       0.000000       0.000000
# weekday_is_wednesday                0.0       0.000000       0.000000
# weekday_is_thursday                 0.0       0.000000       0.000000
# weekday_is_friday                   0.0       0.000000       0.000000
# is_weekend                          0.0       0.000000       0.000000
# LDA_00                              0.0       0.025051       0.033387
# LDA_01                              0.0       0.025012       0.033345
# LDA_02                              0.0       0.028571       0.040004
# LDA_03                              0.0       0.028571       0.040001
# LDA_04                              0.0       0.028574       0.040727
# global_subjectivity                 0.0       0.396167       0.453457
# global_rate_positive_words          0.0       0.028384       0.039023
# rate_positive_words                 0.0       0.600000       0.710526
# max_positive_polarity               0.0       0.600000       0.800000
# min_negative_polarity              -1.0      -0.700000      -0.500000
# max_negative_polarity              -1.0      -0.125000      -0.100000
# title_sentiment_polarity           -1.0       0.000000       0.000000
# abs_title_subjectivity              0.0       0.166667       0.500000
# year                             2013.0    2013.000000    2014.000000
# ln_n_tokens_content                 0.0       5.509388       6.016157
# ln_num_hrefs                        0.0       1.609438       2.197225
# ln_num_imgs                         0.0       0.693147       0.693147
# ln_num_videos                       0.0       0.000000       0.000000
# ln_kw_max_min                       0.0       6.100319       6.493754
# ln_kw_min_max                       0.0       0.000000       7.244942
# ln_kw_avg_avg                       0.0       7.776304       7.962442
# ln_self_reference_avg_sharess       0.0       6.889782       7.696667
# ln_global_rate_negative_words       0.0       0.009569       0.015221
# ln_min_positive_polarity            0.0       0.048790       0.095310
# ln_abs_title_sentiment_polarity     0.0       0.000000       0.000000
#
#                                            75%            max
# n_tokens_title                       12.000000      23.000000
# num_keywords                          9.000000      10.000000
# data_channel_is_lifestyle             0.000000       1.000000
# data_channel_is_entertainment         0.000000       1.000000
# data_channel_is_socmed                0.000000       1.000000
# kw_avg_min                          357.000000   42827.857143
# kw_max_max                       843300.000000  843300.000000
# kw_avg_max                       330980.000000  843300.000000
# weekday_is_monday                     0.000000       1.000000
# weekday_is_tuesday                    0.000000       1.000000
# weekday_is_wednesday                  0.000000       1.000000
# weekday_is_thursday                   0.000000       1.000000
# weekday_is_friday                     0.000000       1.000000
# is_weekend                            0.000000       1.000000
# LDA_00                                0.240958       0.926994
# LDA_01                                0.150831       0.925947
# LDA_02                                0.334218       0.919999
# LDA_03                                0.375763       0.926534
# LDA_04                                0.399986       0.927191
# global_subjectivity                   0.508333       1.000000
# global_rate_positive_words            0.050279       0.155488
# rate_positive_words                   0.800000       1.000000
# max_positive_polarity                 1.000000       1.000000
# min_negative_polarity                -0.300000       0.000000
# max_negative_polarity                -0.050000       0.000000
# title_sentiment_polarity              0.150000       1.000000
# abs_title_subjectivity                0.500000       0.500000
# year                               2014.000000    2014.000000
# ln_n_tokens_content                   6.575076       9.044876
# ln_num_hrefs                          2.708050       5.720312
# ln_num_imgs                           1.609438       4.859812
# ln_num_videos                         0.693147       4.521789
# ln_kw_max_min                         6.908755      12.606193
# ln_kw_min_max                         8.974745      13.645079
# ln_kw_avg_avg                         8.189031      10.682093
# ln_self_reference_avg_sharess         8.556606      13.645079
# ln_global_rate_negative_words         0.021506       0.169685
# ln_min_positive_polarity              0.095310       0.693147
# ln_abs_title_sentiment_polarity       0.223144       0.693147

# %% [markdown]
# # Model Creation
#
# ## Training and Testing Split
#
#
# For training and testing purposes, we use 80% of the observations for training and 20% for testing. This process is repeated three times and uses the shuffle split cross validation method built into scikit-learn.

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn import metrics as mt
from sklearn.svm import SVC

df_tree = df.copy()

# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ...  dataframe in which to record results of model metrics
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

results_table_labels = ['n_features', 'max_depth', 'process_time', 'accuracy', 'recall', 'precision', 'f1_score']
df_results = pd.DataFrame(columns = results_table_labels)

# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ...  separate X and y matrices 
# ...
# ...  convert to numpy matrices by calling 'values' on the pandas data frames
# ...  they are now simple matrices for compatibility with scikit-learn
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

if 'popular' in df_tree:
    y = df_tree['popular'].values         # set 'popular' as dependent
    del df_tree['popular']                # remove from dataset
    X = df_tree.values                    # use everything else for independent EVs

# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ...  setup cross-validation in sklearn
# ...
# ...  split into training and test sets
# ....  --> 3 folds
# ...   --> 80% / 20% training / test
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

num_cv_iterations = 3

num_instances = len(y)

cv_object = ShuffleSplit(n_splits = num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %% [markdown]
# ***
#
# ## c. __Decision Tree__
#
# ***

# %% [markdown]
# First, to prepare the data for the Decision Tree classifier, the data is split into training and test using the indices in the Cross Validation object.

# %%
for train_indices, test_indices in cv_object.split(X, y): 
    X_train = X[train_indices]
    y_train = y[train_indices]    
    X_test = X[test_indices]
    y_test = y[test_indices]

# %%
print('\n----------------------------------------------------')
print('\tDecision Tree - --- --- --- --- --- --- --- ---')
print('----------------------------------------------------')
 

for idepth in range(0, 20):
    
    max_tree_depth = (idepth + 1)
    tic = time.clock()

# ...  get classifier object

    classifier_tree = tree.DecisionTreeClassifier(max_depth = max_tree_depth)

    classifier_tree = classifier_tree.fit(X_train, y_train)
    
    # ... print out process time

    toc = time.clock()
    
# ... test set predictions

    y_hat = classifier_tree.predict(X_test)

# ... model classification metrics

    acc = mt.accuracy_score(y_test, y_hat)
    rec = mt.recall_score(y_test, y_hat)
    pre = mt.precision_score(y_test, y_hat)
    f1s = mt.f1_score(y_test, y_hat)
    conf = mt.confusion_matrix(y_test, y_hat)

    print('\n----------------------------------------------------')
    print('Accuracy  = %9.3f' % acc )
    print('Recall    = %9.3f' % rec )
    print('Precision = %9.3f' % pre )
    print('F1 Score  = %9.3f' % f1s )
    print('\n----------------------------------------------------')
    print('Confusion matrix\n', conf)
    print('----------------------------------------------------')

# ... add model metrics to results data frame

    new_row = [len(df_tree.columns), max_tree_depth, toc-tic, acc, rec, pre, f1s]

    df_results.loc[len(df_results)] = new_row

    print(df_results)
# Out:
# ----------------------------------------------------
# 	Decision Tree - --- --- --- --- --- --- --- ---
# ----------------------------------------------------
#
# ----------------------------------------------------
# Accuracy  =     0.597
# Recall    =     0.575
# Precision =     0.603
# F1 Score  =     0.588
#
# ----------------------------------------------------
# Confusion matrix
#  [[2450 1506]
#  [1689 2284]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy   recall  precision  f1_score
# 0        39.0        1.0      0.088838  0.597049  0.57488   0.602639  0.588432
#
# ----------------------------------------------------
# Accuracy  =     0.611
# Recall    =     0.490
# Precision =     0.647
# F1 Score  =     0.558
#
# ----------------------------------------------------
# Confusion matrix
#  [[2895 1061]
#  [2026 1947]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
#
#    f1_score
# 0  0.588432
# 1  0.557800
#
# ----------------------------------------------------
# Accuracy  =     0.631
# Recall    =     0.560
# Precision =     0.654
# F1 Score  =     0.604
#
# ----------------------------------------------------
# Confusion matrix
#  [[2780 1176]
#  [1747 2226]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
#
# ----------------------------------------------------
# Accuracy  =     0.630
# Recall    =     0.645
# Precision =     0.627
# F1 Score  =     0.636
#
# ----------------------------------------------------
# Confusion matrix
#  [[2432 1524]
#  [1409 2564]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
#
# ----------------------------------------------------
# Accuracy  =     0.638
# Recall    =     0.585
# Precision =     0.656
# F1 Score  =     0.618
#
# ----------------------------------------------------
# Confusion matrix
#  [[2738 1218]
#  [1649 2324]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4        39.0        5.0      0.378564  0.638416  0.584948   0.656126
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
# 4  0.618496
#
# ----------------------------------------------------
# Accuracy  =     0.646
# Recall    =     0.638
# Precision =     0.649
# F1 Score  =     0.643
#
# ----------------------------------------------------
# Confusion matrix
#  [[2589 1367]
#  [1440 2533]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4        39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5        39.0        6.0      0.408506  0.645983  0.637553   0.649487
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
# 4  0.618496
# 5  0.643465
#
# ----------------------------------------------------
# Accuracy  =     0.635
# Recall    =     0.607
# Precision =     0.644
# F1 Score  =     0.625
#
# ----------------------------------------------------
# Confusion matrix
#  [[2622 1334]
#  [1561 2412]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4        39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5        39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6        39.0        7.0      0.501621  0.634885  0.607098   0.643887
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
# 4  0.618496
# 5  0.643465
# 6  0.624951
#
# ----------------------------------------------------
# Accuracy  =     0.642
# Recall    =     0.628
# Precision =     0.647
# F1 Score  =     0.637
#
# ----------------------------------------------------
# Confusion matrix
#  [[2597 1359]
#  [1479 2494]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4        39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5        39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6        39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7        39.0        8.0      0.569203  0.642073  0.627737   0.647288
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
# 4  0.618496
# 5  0.643465
# 6  0.624951
# 7  0.637363
#
# ----------------------------------------------------
# Accuracy  =     0.638
# Recall    =     0.623
# Precision =     0.643
# F1 Score  =     0.633
#
# ----------------------------------------------------
# Confusion matrix
#  [[2580 1376]
#  [1498 2475]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4        39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5        39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6        39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7        39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8        39.0        9.0      0.634935  0.637533  0.622955   0.642690
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
# 4  0.618496
# 5  0.643465
# 6  0.624951
# 7  0.637363
# 8  0.632669
#
# ----------------------------------------------------
# Accuracy  =     0.632
# Recall    =     0.603
# Precision =     0.641
# F1 Score  =     0.622
#
# ----------------------------------------------------
# Confusion matrix
#  [[2616 1340]
#  [1576 2397]]
# ----------------------------------------------------
#    n_features  max_depth  process_time  accuracy    recall  precision  \
# 0        39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1        39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2        39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3        39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4        39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5        39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6        39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7        39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8        39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9        39.0       10.0      0.688797  0.632236  0.603322   0.641424
#
#    f1_score
# 0  0.588432
# 1  0.557800
# 2  0.603661
# 3  0.636149
# 4  0.618496
# 5  0.643465
# 6  0.624951
# 7  0.637363
# 8  0.632669
# 9  0.621790
# ----------------------------------------------------
# Accuracy  =     0.627
# Recall    =     0.607
# Precision =     0.634
# F1 Score  =     0.620
#
# ----------------------------------------------------
# Confusion matrix
#  [[2563 1393]
#  [1563 2410]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
#
# ----------------------------------------------------
# Accuracy  =     0.618
# Recall    =     0.595
# Precision =     0.626
# F1 Score  =     0.610
#
# ----------------------------------------------------
# Confusion matrix
#  [[2542 1414]
#  [1611 2362]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
#
# ----------------------------------------------------
# Accuracy  =     0.617
# Recall    =     0.605
# Precision =     0.621
# F1 Score  =     0.613
#
# ----------------------------------------------------
# Confusion matrix
#  [[2489 1467]
#  [1571 2402]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
#
# ----------------------------------------------------
# Accuracy  =     0.603
# Recall    =     0.562
# Precision =     0.614
# F1 Score  =     0.587
#
# ----------------------------------------------------
# Confusion matrix
#  [[2550 1406]
#  [1740 2233]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
#
# ----------------------------------------------------
# Accuracy  =     0.610
# Recall    =     0.581
# Precision =     0.618
# F1 Score  =     0.599
#
# ----------------------------------------------------
# Confusion matrix
#  [[2530 1426]
#  [1666 2307]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
# 14        39.0       15.0      0.868206  0.610039  0.580670   0.618002
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
# 14  0.598754
#
# ----------------------------------------------------
# Accuracy  =     0.602
# Recall    =     0.552
# Precision =     0.614
# F1 Score  =     0.581
#
# ----------------------------------------------------
# Confusion matrix
#  [[2578 1378]
#  [1781 2192]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
# 14        39.0       15.0      0.868206  0.610039  0.580670   0.618002
# 15        39.0       16.0      0.955469  0.601589  0.551724   0.614006
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
# 14  0.598754
# 15  0.581201
# ----------------------------------------------------
# Accuracy  =     0.593
# Recall    =     0.566
# Precision =     0.600
# F1 Score  =     0.582
#
# ----------------------------------------------------
# Confusion matrix
#  [[2455 1501]
#  [1726 2247]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
# 14        39.0       15.0      0.868206  0.610039  0.580670   0.618002
# 15        39.0       16.0      0.955469  0.601589  0.551724   0.614006
# 16        39.0       17.0      1.003430  0.593013  0.565568   0.599520
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
# 14  0.598754
# 15  0.581201
# 16  0.582049
#
# ----------------------------------------------------
# Accuracy  =     0.588
# Recall    =     0.546
# Precision =     0.598
# F1 Score  =     0.571
#
# ----------------------------------------------------
# Confusion matrix
#  [[2495 1461]
#  [1803 2170]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
# 14        39.0       15.0      0.868206  0.610039  0.580670   0.618002
# 15        39.0       16.0      0.955469  0.601589  0.551724   0.614006
# 16        39.0       17.0      1.003430  0.593013  0.565568   0.599520
# 17        39.0       18.0      1.021560  0.588347  0.546187   0.597632
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
# 14  0.598754
# 15  0.581201
# 16  0.582049
# 17  0.570752
#
# ----------------------------------------------------
# Accuracy  =     0.585
# Recall    =     0.560
# Precision =     0.590
# F1 Score  =     0.574
#
# ----------------------------------------------------
# Confusion matrix
#  [[2413 1543]
#  [1750 2223]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
# 14        39.0       15.0      0.868206  0.610039  0.580670   0.618002
# 15        39.0       16.0      0.955469  0.601589  0.551724   0.614006
# 16        39.0       17.0      1.003430  0.593013  0.565568   0.599520
# 17        39.0       18.0      1.021560  0.588347  0.546187   0.597632
# 18        39.0       19.0      1.016344  0.584689  0.559527   0.590281
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
# 14  0.598754
# 15  0.581201
# 16  0.582049
# 17  0.570752
# 18  0.574493
#
# ----------------------------------------------------
# Accuracy  =     0.588
# Recall    =     0.567
# Precision =     0.594
# F1 Score  =     0.580
#
# ----------------------------------------------------
# Confusion matrix
#  [[2413 1543]
#  [1720 2253]]
# ----------------------------------------------------
#     n_features  max_depth  process_time  accuracy    recall  precision  \
# 0         39.0        1.0      0.088838  0.597049  0.574880   0.602639
# 1         39.0        2.0      0.155376  0.610670  0.490058   0.647274
# 2         39.0        3.0      0.210621  0.631353  0.560282   0.654321
# 3         39.0        4.0      0.278757  0.630092  0.645356   0.627202
# 4         39.0        5.0      0.378564  0.638416  0.584948   0.656126
# 5         39.0        6.0      0.408506  0.645983  0.637553   0.649487
# 6         39.0        7.0      0.501621  0.634885  0.607098   0.643887
# 7         39.0        8.0      0.569203  0.642073  0.627737   0.647288
# 8         39.0        9.0      0.634935  0.637533  0.622955   0.642690
# 9         39.0       10.0      0.688797  0.632236  0.603322   0.641424
# 10        39.0       11.0      0.696538  0.627191  0.606595   0.633710
# 11        39.0       12.0      0.799937  0.618489  0.594513   0.625530
# 12        39.0       13.0      0.854701  0.616850  0.604581   0.620832
# 13        39.0       14.0      0.881816  0.603229  0.562044   0.613630
# 14        39.0       15.0      0.868206  0.610039  0.580670   0.618002
# 15        39.0       16.0      0.955469  0.601589  0.551724   0.614006
# 16        39.0       17.0      1.003430  0.593013  0.565568   0.599520
# 17        39.0       18.0      1.021560  0.588347  0.546187   0.597632
# 18        39.0       19.0      1.016344  0.584689  0.559527   0.590281
# 19        39.0       20.0      1.048146  0.588473  0.567078   0.593519
#
#     f1_score
# 0   0.588432
# 1   0.557800
# 2   0.603661
# 3   0.636149
# 4   0.618496
# 5   0.643465
# 6   0.624951
# 7   0.637363
# 8   0.632669
# 9   0.621790
# 10  0.619856
# 11  0.609627
# 12  0.612599
# 13  0.586705
# 14  0.598754
# 15  0.581201
# 16  0.582049
# 17  0.570752
# 18  0.574493
# 19  0.579997

# %%
type(list(set(df.popular)))

y_hat

y_train
# Out:
# array([False, False, False, ...,  True, False,  True], dtype=bool)

# %%
type(df_tree.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
import graphviz 

dot_data = tree.export_graphviz(classifier_tree, out_file = None) 

graph = graphviz.Source(dot_data) 

graph.render("mashable") 

dot_data = tree.export_graphviz(classifier_tree, out_file = None, 
                        feature_names = df_tree.columns,
                        class_names = ['popular', 'not popular'],
                        filled = True, rounded = True,  
                        special_characters = True)  
graph = graphviz.Source(dot_data)  

graph.render("mashable")
# Out:
# 'mashable.pdf'
