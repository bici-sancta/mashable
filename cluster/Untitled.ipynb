# %%
import pandas as pd
import time


# set required variables for model comparison

tsne_tbl = pd.DataFrame(columns = [
    'model_name',
    'perplexity',
    'kl_divergence',
    'process_time'])

i_index = []
i_index = 0

# preparation for cross validation and model comparison, each classifier is appended once model is fit

models = []

# %%
for perplex in [5, 10, 20, 50, 75, 100, 200, 400, 1000] :

    i_index = i_index + 1
    tic = time.clock()
    toc = time.clock()
    print (toc - tic)
    
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# ... - save statistics for model comparison
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-

    exe_time = '{0:.4f}'.format(toc-tic)
    
    raw_data = {
    'model_name' : 't-SNE - 2D',
    'perplexity' : perplex,
    'process_time' : exe_time
    }

    df_tbl = pd.DataFrame(raw_data,
                            columns = ['model_name',
                                       'perplexity',
                                       'kl_divergence',
                                       'process_time'],
                            index = [i_index])
    
    tsne_tbl = tsne_tbl.append(df_tbl)
    
    
tsne_tbl
# Out:
# 2.9999999999752447e-06
# 4.000000000115023e-06
# 2.9999999999752447e-06
# 2.9999999999752447e-06
# 2.9999999999752447e-06
# 2.9999999999752447e-06
# 2.9999999999752447e-06
# 2.9999999999752447e-06
# 2.9999999999752447e-06
#    model_name perplexity kl_divergence process_time
# 1  t-SNE - 2D          5           NaN       0.0000
# 2  t-SNE - 2D         10           NaN       0.0000
# 3  t-SNE - 2D         20           NaN       0.0000
# 4  t-SNE - 2D         50           NaN       0.0000
# 5  t-SNE - 2D         75           NaN       0.0000
# 6  t-SNE - 2D        100           NaN       0.0000
# 7  t-SNE - 2D        200           NaN       0.0000
# 8  t-SNE - 2D        400           NaN       0.0000
# 9  t-SNE - 2D       1000           NaN       0.0000
